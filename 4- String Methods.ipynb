# %% [markdown]
# ## **String interpolation (f-strings)**

# %%
name = "emre"
age = 24
print(f"Benim adim {name} yasim {age}")
# Out:
# Benim adim emre yasim 24

# %% [markdown]
# 1. **F-strings are also able to evaluate expressions inside the curly braces, which can be very handy. For example:**

# %%
x = 10
y = 20
print(f"the sum of x and y is {x+y}")
# Out:
# x and y plus 30

# %% [markdown]
# ## **str.format()**

# %%
name = "emre"
age = 24
print('Adim {} yasim {}'.format(name,age))
# Out:
# Adim emre yasim 24

# %% [markdown]
# ## **Raw String (r’’)**

# %%
regular_string = "C:\new_folder\file.txt"
print("Regular String:", regular_string)
# Out:
# Regular String: C:
# ew_folderile.txt

# %% [markdown]
# In the regular string regular_string variable, the backslashes (\n) are interpreted as escape sequences. Therefore, \n represents a newline character, which would lead to an incorrect file path representation.

# %%
regular_string = r"C:\new_folder\file.txt"
print("Regular String:", regular_string)
# Out:
# Regular String: C:\new_folder\file.txt

# %% [markdown]
# <code>re</code> libraries <code> search, split, findall</code>

# %%
import re

# %%
s1 = "the bodyguard is the best guard"
pattern = r'best'
research = re.search(pattern,s1) # first aranacak kelime, second hangi cumelede

if research:
    print("bulundu")
else: 
    print("bulunamadi")
# Out:
# bulundu

# %%
my_string="Hello" 
split_text = my_string.split(",",1)
split_text
# Out:
# ['Hello']

# %%
my_string="Hello" 
trimmed = my_string.strip()
trimmed
# Out:
# 'Hello'
